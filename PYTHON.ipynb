# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# READ MAKEDB TAB FILE FOR EACH SAMPLE / PATIENT

df=pd.read_table('resultsHC_38_BB_genotyped_db-pass-props.tab')

#GET V-D-J FAMILY,GENE,ALLELE CALLS (SINGLE ASSINGMENT OR FIRST MENTIONED)

df['V_GENE'] = df['V_CALL'].str.split('*',1).str[0]
df['V_ALLELE']=df['V_CALL'].str.split(',',1).str[0]
df['V_FAMILY'] = df['V_CALL'].str.split('-',1).str[0]

df['D_GENE'] = df['D_CALL'].str.split('*',1).str[0]
df['D_ALLELE']=df['D_CALL'].str.split(',',1).str[0]
df['D_FAMILY'] = df['D_CALL'].str.split('-',1).str[0]

df['J_GENE'] = df['J_CALL'].str.split('-',1).str[0]
df['J_FAMILY'] = df['J_CALL'].str.split('*',1).str[0]

df

#REMOVE NONFUNCTIONAL GENES ("OR")

df2=df[~df.V_CALL.str.contains('OR')]

#REMOVE NONFUNCETIONAL SEQUENCES 
# STOP CODONS 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# READ MAKEDB TAB FILE FOR EACH SAMPLE / PATIENT

df=pd.read_table('resultsHC_38_BB_genotyped_db-pass-props.tab')

#GET V-D-J FAMILY,GENE,ALLELE CALLS (SINGLE ASSINGMENT OR FIRST MENTIONED)

df['V_GENE'] = df['V_CALL'].str.split('*',1).str[0]
df['V_ALLELE']=df['V_CALL'].str.split(',',1).str[0]
df['V_FAMILY'] = df['V_CALL'].str.split('-',1).str[0]

df['D_GENE'] = df['D_CALL'].str.split('*',1).str[0]
df['D_ALLELE']=df['D_CALL'].str.split(',',1).str[0]
df['D_FAMILY'] = df['D_CALL'].str.split('-',1).str[0]

df['J_GENE'] = df['J_CALL'].str.split('-',1).str[0]
df['J_FAMILY'] = df['J_CALL'].str.split('*',1).str[0]

df

#REMOVE NONFUNCTIONAL GENES ("OR")

df2=df[~df.V_CALL.str.contains('OR')]

#REMOVE NONFUNCETIONAL SEQUENCES 
# STOP CODONS 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# READ MAKEDB TAB FILE FOR EACH SAMPLE / PATIENT

df=pd.read_table('resultsHC_38_BB_genotyped_db-pass-props.tab')

#GET V-D-J FAMILY,GENE,ALLELE CALLS (SINGLE ASSINGMENT OR FIRST MENTIONED)

df['V_GENE'] = df['V_CALL'].str.split('*',1).str[0]
df['V_ALLELE']=df['V_CALL'].str.split(',',1).str[0]
df['V_FAMILY'] = df['V_CALL'].str.split('-',1).str[0]

df['D_GENE'] = df['D_CALL'].str.split('*',1).str[0]
df['D_ALLELE']=df['D_CALL'].str.split(',',1).str[0]
df['D_FAMILY'] = df['D_CALL'].str.split('-',1).str[0]

df['J_GENE'] = df['J_CALL'].str.split('-',1).str[0]
df['J_FAMILY'] = df['J_CALL'].str.split('*',1).str[0]

df

#REMOVE NONFUNCTIONAL GENES ("OR")

df2=df[~df.V_CALL.str.contains('OR')]

#REMOVE NONFUNCETIONAL SEQUENCES 

# STOP CODONS 
#df2=df2[~df2.STOP.str.contains('TRUE') == True]
df2
# INDELS 
#df2=df2[~df2.INDELS.str.contains('TRUE')]

# IN_FRAME
#df2=df2[~df2.IN_FRAME.str.contains('TRUE')]

#FUNCTIONAL 
#df2=df2[~df2.FUNCTIONAL.str.contains('TRUE')]

#JUNCTION 
#AA TRANSLATION IN FRAME  OF THE SEQUENCE DEMENDS MODULO 0 WHEN DIVIDING BY 3

df2=df2[df2.JUNCTION_LENGTH%3==0]

#check 
np.unique(df2['JUNCTION_LENGTH']).shape
np.unique(df['JUNCTION_LENGTH']).shape # there are only 33 unique values which means we can use it or try to - as a feature@

#AA TRANSLATION OF THE SEQUENCE DEMENDS MORE THEN 3 AA 
df2=df2[df2.JUNCTION_LENGTH>=12]
#df2.info()

#REMOVE NA's in JUNCTION 
#df2=df2[~df2.JUNCTION_LENGTH=='NA']
df2['JUNCTION_LENGTH'][8000:8500]
# Out:
# 8001    54
# 8002    54
# 8003    72
# 8004    69
# 8005    60
# 8006    39
# 8007    51
# 8008    66
# 8009    72
# 8010    54
# 8011    54
# 8012    72
# 8013    63
# 8014    69
# 8015    48
# 8016    54
# 8017    72
# 8018    54
# 8019    75
# 8020    57
# 8021    60
# 8022    54
# 8023    72
# 8024    69
# 8025    42
# 8026    48
# 8027    66
# 8028    60
# 8029    66
# 8030    48
#         ..
# 8472    54
# 8473    63
# 8474    75
# 8475    66
# 8476    54
# 8477    60
# 8478    63
# 8479    57
# 8480    63
# 8481    42
# 8482    45
# 8483    54
# 8484    51
# 8485    60
# 8486    66
# 8487    57
# 8488    45
# 8489    57
# 8490    30
# 8491    36
# 8492    66
# 8493    33
# 8494    54
# 8495    48
# 8496    57
# 8497    72
# 8498    57
# 8499    48
# 8500    57
# 8501    63
# Name: JUNCTION_LENGTH, Length: 500, dtype: int64

# %%
from Bio.Seq import Seq
from Bio.Alphabet import generic_dna


df2['JUNCTION_AA']=df2['JUNCTION'].apply(lambda x: Seq(x, generic_dna))

df2['JUNCTION_AA'][1:8000]= df2['JUNCTION_AA'][1:8000].apply(lambda x: x.translate())



#df2['JUNCTION_AA'] = df2['JUNCTION'].translate()
# Out:
# /home/reut/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
